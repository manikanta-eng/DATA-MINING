# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta-eng/DATA-MINING/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data={'category':['A','B','C','A','B']}
df=pd.DataFrame(data)
df
# Out:
#   category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
label_Encoder=LabelEncoder()
df['label_Encoder']=label_Encoder.fit_transform(df['category'])
df
# Out:
#    category  label_Encoder
# 0         0              0
# 1         1              1
# 2         2              2
# 3         0              0
# 4         1              1

# %%
one_hot_encoded=pd.get_dummies(df['category'],prefix='category')
df=pd.concat([df,one_hot_encoded],axis=1)
df
# Out:
#    category  label_Encoder  category_0  category_1  category_2
# 0         0              0        True       False       False
# 1         1              1       False        True       False
# 2         2              2       False       False        True
# 3         0              0        True       False       False
# 4         1              1       False        True       False

# %% [markdown]
# ##creating derived column##

# %%
from datetime import datetime
data={'Name':['Alice','Bob'],'Date_of_Birth':['1990-05-14','1995-08-20']}
df=pd.DataFrame(data)
df
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1995-08-20

# %%
df['Date_of_Birth']=pd.to_datetime(df['Date_of_Birth'])
df
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1995-08-20

# %%
current_year=datetime.now().year
df['Age']=current_year-df['Date_of_Birth'].dt.year
df
# Out:
#     Name Date_of_Birth  Age
# 0  Alice    1990-05-14   35
# 1    Bob    1995-08-20   30

# %%
data={'category': ['A','A','B','B','C'],'Value':[10,20,10,30,40]}
df=pd.DataFrame(data)
df
# Out:
#   category  Value
# 0        A     10
# 1        A     20
# 2        B     10
# 3        B     30
# 4        C     40

# %%
#group by and aggregate
grouped=df.groupby('category').agg({'Value':{'sum','mean'}})
print("Grouped data\n",grouped)
# Out:
# Grouped data
#           Value
#           mean sum
# category
# A         15.0  30
# B         20.0  40
# C         40.0  40

# %%
#pivot table
pivot_table=df.pivot_table(index='category',values='Value',aggfunc=['sum','mean'])
print("\nPivot Table\n",pivot_table)
# Out:
# Pivot Table
#             sum  mean
#          Value Value
# category
# A           30  15.0
# B           40  20.0
# C           40  40.0
